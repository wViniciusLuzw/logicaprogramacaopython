# %% [markdown]
# <a href="https://colab.research.google.com/github/wViniciusLuzw/logicaprogramacaopython/blob/main/variaveis%20e%20operadores%20aritmeticos/Exerc%C3%ADcios/Exerc%C3%ADciosEmPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1) Identifique os dados de entrada, processamento e saída no algoritmo abaixo:
#
# Receba Valor da peça (VALOR) Receba Quantidade de peças (QTDE) Entrada
#
# Calcule o valor total da peça (VT) (VT = QTDE * VALOR) P
#
# Mostre o seu valor total (VT) Saída

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print("Este programa calculará o preço a ser pago para certa quantidade de peças")
#Entrada
VALOR = float(input("Digite o valor da peça "))
QTDE = float(input("Digite a quantidade de peças "))

#Processamento
VT =  QTDE * VALOR

#Saída
print("O valor total a ser pago é ", VT)
# Out:
# Este programa calculará o preço a ser pago para certa quantidade de peças
# Digite o valor da peça 7
# Digite a quantidade de peças 4
# O valor total a ser pago é  28.0

# %% [markdown]
# 2) Faça um algoritmo para “Calcular o estoque médio de uma peça”, sendo que
#
# ESTOQUEMEDIO = (QUANTIDADE_MINIMA + QUANTIDADE_MAXIMA) /2
# QTDEMIN, QMAXIMA (Entrada)
#
# ESTOQUEMEDIO = (QUANTIDADE_MINIMA +
# QUANTIDADE_MAXIMA) /2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print("Este programa irá calcular o estoque médio")
#Entrada
QTDEMIN = float(input("Quantidade minima de peças "))
QTDEMAX = float(input("Quantidade maximo de peças "))

#Processamento
EST_MED = (QTDEMIN + QTDEMAX)/2

#Saída
print("O Estoque médio é ", EST_MED)
# Out:
# Este programa irá calcular o estoque médio
# Quantidade minima de peças 7
# Quantidade maximo de peças 7
# O Estoque médio é  7.0

# %% [markdown]
# 3) Faça um algoritmo que faça conversão de minutos e horas em segundos.
# Solicite ao usuário a hora e os minutos separado.
#
# Por exemplo 4h23 minutos equivale a 4.38
# para fazer cálculos
# matemáticos
#
# Para chegar a essa conclusão: 23/60 = 0,38 4+0,38 = 4,38

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print("Este programa converterá horas e minutos em segundos")
#Entrada
h = float(input("Quantas horas? "))
m = float(input("Quantos minutos? "))

#Processamento
s = m*60 + h*60*60

#Saída
print("O resultado é ", s, "segundos")
# Out:
# Este programa converterá horas e minutos em segundos
# Quantas horas? 1
# Quantos minutos? 0
# O resultado é  3600.0 segundos

# %% [markdown]
# 4) Continuando do exercício anterior, um funcionário trabalha em
# determinada empresa e quer saber quanto irá ganhar de hora extra.Você
# deverá fazer um algoritmo que solicite quantas horas e quantos minutos ele
# trabalhou, solicite horas e minutos de forma separada. Depois pergunte
# quanto ele ganha por hora e informe quanto ele irá ganhar. Sabendo que
# nessa empresa o funcionário ganha 70% a mais pelas horas trabalhadas.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print("Este programa calculará o ganho de hora extra")
#Entrada
h = float(input("Qual foi quantidade de horas trabalhadas "))
m = float(input("Qual foi quantidade de minutos trabalhados "))
val_h = float(input("ganho por hora"))

#Processamento
gan_hora = (m/60 + h)*val_h
gan = (gan_hora*70/100) + gan_hora

#Saída
print("O valor a ser recebido é de ", gan)

# %% [markdown]
# 5) Construa um programa que :
#
# Leia a cotação do dólar.
#
# Leia o valor que quer converter em dolar
#
# Converta esse valor para dolar.
#
# Mostre o resultado

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print("Este programa converterá reais(R$) em dolares(US$)")
#Entrada
cot_dolar = float(input("Qual a do atualmente contação dolar? "))
con_real = float(input("Qual é o valor a ser convertido para dolares? "))

#Processamento
dolar = con_real/cot_dolar

#Saída
print("R$", con_real, "equivale a US$", dolar)
# Out:
# Este programa converterá reais(R$) em dolares(US$)
# Qual a do atualmente contação dolar? 4.5
# Qual é o valor a ser convertido para dolares? 9
# R$ 9.0 equivale a US$ 2.0

# %% [markdown]
# 6) Desenvolva um programa que:
#
# Leia 4 (quatro) números.
#
# Calcule o quadrado para cada um.
#
# Somem todos.
#
# Mostre o resultado

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print("Este programa somará o quadrado de 4(quatro) números")

#Entrada
pri = float(input("Qual é o primeiro número? "))
seg = float(input("Qual é o segundo número? "))
ter = float(input("Qual é o terceiro número? "))
qua = float(input("Qual é o quarto número? "))
#Processamento
soma =  pri*pri + seg*seg + ter*ter + qua*qua

#Saída
print("A soma do quadrados de todos os números é ", soma)
# Out:
# Este programa somará o quadrado de 4(quatro) números
# Qual é o primeiro número? 2
# Qual é o segundo número? 2
# Qual é o terceiro número? 2
# Qual é o quarto número? 2
# A soma do quadrados de todos os números é  16.0

# %% [markdown]
# 7) Construa um algoritmo para pagamento de comissão
# de vendedores de peças, levando-se em consideração
# que sua comissão será de 5% do total da venda e que
# você precisará dos seguintes dados:
#
# Preço unitário da peça
#
# Quantidade vendida
#
# Após isso, calcular a comissão do vendedor e mostrar
# na tela

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print("Este programa calculará pagamento de comissão de vendedores de peças")

#Entrada
pre_uni = float(input("Qual é o preço da peça? "))
qua_ven = float(input("Qual foi a quantidade vendida dessa mesma peça? "))
#Processamento
gan = pre_uni*qua_ven
com = gan*5/100

#Saída
print("O valor da venda é de ", gan)
print("O valor da comissão é de ", com)
# Out:
# Este programa calculará pagamento de comissão de vendedores de peças
# Qual é o preço da peça? 100
# Qual foi a quantidade vendida dessa mesma peça? 60
# O valor da venda é de  6000.0
# O valor da comissão é de  300.0

# %% [markdown]
# 8) O custo ao consumidor de um carro novo é a
# soma do custo de fábrica com a percentagem do
# distribuidor e dos impostos (aplicados, primeiro os
# impostos sobre o custo de fábrica, e depois a
# percentagem do distribuidor sobre o resultado).
# Supondo que a percentagem do distribuidor seja
# de 28% e os impostos 45%. Escrever um algoritmo
# que leia o custo de fábrica de um carro e informe o
# custo ao consumidor do mesmo.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print("Este programa calculará custo de um carro novo é a soma do custo de fábrica com a percentagem do distribuidor e dos impostos")

#Entrada
Cus_fab = float(input("Qual foi o custo de fabricação do veiculo? "))

#Processamento
Cus_impo = Cus_fab + Cus_fab*45/100
Cus_cons = Cus_impo + (Cus_impo*28/100)

#Saída
print("O custo do veiculo incluindo a porcentagem do distribuidor e dos impostos é ", Cus_cons)
# Out:
# Este programa calculará custo de um carro novo é a soma do custo de fábrica com a percentagem do distribuidor e dos impostos
# Qual foi o custo de fabricação do veiculo?25000
# O custo do veiculo incluindo a percentagem do distribuidor e dos impostos é  46400.0

# %% [markdown]
# 9) Faça um algoritmo que calcule quanto o usuário irá gastar de gasolina
# em uma viagem, solicitando os seguinte dados:
#
# Kilometros a percorrer
#
# Quanto Seu carro consome de Gasolina
#
# Preço Médio da Gasolina

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print("Este programa calculará o gasto de gasolina em uma viagem")

#Entrada
km = float(input("Quantos Km foram percorridos? "))
cons= float(input("Qual é o consumo de gasolina do carro? "))
pre_gas= float(input("Qual é o preço médio da gasolina? "))
#Processamento
gast = (km/cons)*pre_gas
gast_tt = gast*2
#Saída
print("O custo para a partida é de ", gast, "já o custo de partida e volta é de ", gast_tt)
# Out:
# Este programa calculará o gasto de gasolina em uma viagem
# Quantos Km foram percorridos? 450
# Qual é o consumo de gasolina do carro? 10
# Qual é o preço médio da gasolina? 4.5
# O custo para a partida é de  202.5 já o custo de partida e volta é de  405.0

# %% [markdown]
# 10) Faça um algoritmo para prever a velocidade média de um carro,
# sabendo que futuramente esse programa irá calcular também o valor da
# multa, se ele tiver acima da velocidade, para isso solicite os seguintes
# dados: Obs. A velocidade máxima dessa estrada é 110Km/h
#
# Qual o percurso percorrido: Ex. 150km
#
# Qual o tempo gasto nesse percurso: Ex. 1h13
#
# O Resultado deverá ser: 122km/h

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print("Este programa calcula a velocidade média de um veiculo")

#Entrada
Km = float(input("Quantos Km foram percorridos? "))
h_gas = float(input("Em quantas horas? "))
m_gas = float(input("Em quantos minutos? "))

#Processamento
veloc = Km/(h_gas + m_gas/60)

#Saída
print("A velocidade média desse veiculo é de ", veloc)
# Out:
# Este programa calcula a velocidade média de um veiculo
# Quantos Km foram percorridos?150
# Em quantas horas1
# Em quantos minutos13
# A velocidade média desse veiculo é de  123.2876712328767
